# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
r=np.linspace(0,1,num=10000)
print("random number btw o to 1=",r);
m=9.11*10**(-31);
print("mass of the elctron=",m);
T1=30;
print("Temperature of hot plasma=",T1);
T2=4;
print("Temperature of cold plasma=",T2);

Eps1=(3/2)*T1;
print("the value of epsilon=",Eps1);
Eps2=(3/2)*T2;
print("the value of epsilon=",Eps2);

eg=1.602*10**(-19);
print("charge of electron=",eg);
# Out:
# random number btw o to 1= [0.00000000e+00 1.00010001e-04 2.00020002e-04 ... 9.99799980e-01
#  9.99899990e-01 1.00000000e+00]
# mass of the elctron= 9.11e-31
# Temperature of hot plasma= 30
# Temperature of cold plasma= 4
# the value of epsilon= 45.0
# the value of epsilon= 6.0
# charge of electron= 1.602e-19

# %%
z=np.cos(2*np.pi*r);
print("The value of cos phi=", z);
x=np.sin(np.arccos((1-r)**0.5));
print("The value of sin theta=", x);
p=np.cos(np.arccos((1-r)**0.5));
print("The value of cos theta=", p);
# Out:
# The value of cos phi= [1.         0.9999998  0.99999921 ... 0.99999921 0.9999998  1.        ]
# The value of sin theta= [0.         0.0100005  0.01414284 ... 0.99989998 0.99994999 1.        ]
# The value of cos theta= [1.00000000e+00 9.99949994e-01 9.99899985e-01 ... 1.41428428e-02
#  1.00005000e-02 6.12323400e-17]

# %%
vx1=(((2*eg*Eps1)/m)**0.5)*x*z;
print("The values of vx of hot plasma=",vx1);
vx2=(((2*eg*Eps2)/m)**0.5)*x*z;
print("The values of vx of cold plasma=",vx2);
vx3=(((2*eg*Eps1)/m)**0.5)*x*z+(((2*eg*Eps2)/m)**0.5)*x*z;
print("The values of vx of hot plus cold plasma=",vx3);

vpf1= ((m/(2*eg))**0.5)*(np.exp((-m*vx1*vx1)/(2*eg*T1)))
print("The values of vpf of hot plasma",vpf1)
vpf2= ((m/(2*eg))**0.5)*(np.exp((-m*vx2*vx2)/(2*eg*T2)))
print("The values of vpf of cold plasma",vpf2)
vpf3= ((m/(2*eg))**0.5)*(np.exp((-m*vx1*vx1)/(2*eg*T1)))+((m/(2*eg))**0.5)*(np.exp((-m*vx2*vx2)/(2*eg*T2)))
print("The values of vpf of hot plus cold plasma",vpf3)

fig , ax= plt.subplots()
ax.plot(vx1,vpf1,color="red",label="hot")
ax.plot(vx2,vpf2,color="blue",label="cold")
ax.plot(vx2,vpf3,color="green",label="hot plus cold")
plt.xlabel('vx - axis')
plt.ylabel('vpf - axis')
plt.title(' Hot and Cold cosine plasma VX vs. VDF graph !')

plt.show()
# Out:
# The values of vx of hot plasma= [      0.           39784.59598879   56263.88189604 ... 3977860.42910604
#  3978061.73302327 3978261.45635857]
# The values of vx of cold plasma= [      0.           14527.28044286   20544.66485818 ... 1452509.25841904
#  1452582.76421663 1452655.69286729]
# The values of vx of hot plus cold plasma= [      0.           54311.87643164   76808.54675421 ... 5430369.68752507
#  5430644.4972399  5430917.14922586]
# The values of vpf of hot plasma [1.68621495e-06 1.68596201e-06 1.68570911e-06 ... 3.76359205e-07
#  3.76302081e-07 3.76245411e-07]
# The values of vpf of cold plasma [1.68621495e-06 1.68596201e-06 1.68570911e-06 ... 3.76359205e-07
#  3.76302081e-07 3.76245411e-07]
# The values of vpf of hot plus cold plasma [3.37242989e-06 3.37192402e-06 3.37141822e-06 ... 7.52718409e-07
#  7.52604162e-07 7.52490823e-07]
